# %%
import pandas as pd

# %%
df = pd.read_csv("climate_with_sentiment.csv")

# %%
df.columns
# Out:
# Index(['publish_date', 'media_name', 'title', 'url', 'date', 'year', 'month',
#        'year_month', 'week', 'title_clean', 'sentiment', 'sentiment_label'],
#       dtype='object')

# %%
test_dates = df["date"].sort_values()
print(test_dates)

smallest = test_dates.min()
largest = test_dates.max()

print("Smallest date:", smallest)
print("Largest date:", largest)
# Out:
# 1760    2025-11-07
# 1733    2025-11-07
# 1732    2025-11-07
# 1731    2025-11-07
# 1730    2025-11-07
#            ...
# 8       2026-02-06
# 9       2026-02-06
# 5       2026-02-06
# 1       2026-02-07
# 0       2026-02-07
# Name: date, Length: 1761, dtype: object
# Smallest date: 2025-11-07
# Largest date: 2026-02-07

# %%
df.head()
# Out:
#   publish_date       media_name  \
# 0   2026-02-07     usatoday.com
# 1   2026-02-07  livescience.com
# 2   2026-02-06    bloomberg.com
# 3   2026-02-06      latimes.com
# 4   2026-02-06      latimes.com
#
#                                                title  \
# 0  Polar vortex cold highlights climate change qu...
# 1    Clean energy is surging — with or without Trump
# 2  Why Some Republicans Voted for More Carbon Emi...
# 3  How climate change is threatening the future o...
# 4  Letters to the Editor: Climate change easily s...
#
#                                                  url        date  year  month  \
# 0  https://www.usatoday.com/story/news/nation/202...  2026-02-07  2026      2
# 1  https://www.livescience.com/planet-earth/renew...  2026-02-07  2026      2
# 2  https://www.bloomberg.com/news/articles/2026-0...  2026-02-06  2026      2
# 3  https://www.latimes.com/sports/olympics/story/...  2026-02-06  2026      2
# ...
